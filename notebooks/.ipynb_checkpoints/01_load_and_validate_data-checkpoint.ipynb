# %%
# import necessary libraries
from pathlib import Path
import requests
import pandas as pd

def download_one_file(year: int, month: int, day: int) -> Path:
    """
    Downloads the yellow taxi trip data for a given year and month from Inside Airbnb and saves it as a csv file.

    Args:
    - year (int): The year of the data to download.
    - month (int): The month of the data to download.
    - day (int): The day of the data to download.

    Returns:
    - path (Path): The path to the downloaded csv file.
    """


    URL = f'http://data.insideairbnb.com/united-states/ny/new-york-city/{year}-{month:02d}-{day:02d}/visualisations/listings.csv'
    response = requests.get(URL)

    if response.status_code == 200:
        path = f'../data/raw/new-york-city/{year}-{month:02d}-{day:02d}.csv'
        open(path, 'wb').write(response.content)
        return path
    else:
        raise Exception(f'{URL} is not available.')

# %%
# explore and validate one single file
download_one_file(year=2023, month=10, day=1)

df = pd.read_csv('../data/raw/new-york-city/2023-10-01.csv')
df.head(20)
# Out:
#        id                                               name  host_id  \
# 0    2595  Rental unit in New York · ★4.68 · Studio · 1 b...     2845
# 1    5121  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...     7356
# 2    6848  Rental unit in Brooklyn · ★4.58 · 2 bedrooms ·...    15991
# 3    6872  Condo in New York · 1 bedroom · 1 bed · 1 shar...    16104
# 4    7064  Loft in Brooklyn · ★4.91 · 1 bedroom · 1 bed ·...    17297
# 5    7097  Home in Brooklyn · ★4.88 · 1 bedroom · 2 beds ...    17571
# 6    7801  Place to stay in Brooklyn · ★4.89 · 1 bed · 1 ...    21207
# 7    8490  Loft in Brooklyn · ★4.77 · 1 bedroom · 4 beds ...    25183
# 8    9357  Rental unit in New York · ★4.52 · Studio · 1 b...    30193
# 9   10452  Rental unit in Brooklyn · ★4.65 · 1 bedroom · ...    35935
# 10  11943     Home in Brooklyn · 1 bedroom · 2 beds · 1 bath    45445
# 11  12192  Rental unit in New York · ★4.39 · 1 bedroom · ...    46978
# 12  12937  Townhouse in Queens · ★4.91 · 1 bedroom · 1 be...    50124
# 13  12940  Rental unit in Brooklyn · ★4.52 · 1 bedroom · ...    50148
# 14  13808  Townhouse in Brooklyn · ★4.65 · 1 bedroom · 1 ...    54275
# 15  14314  Rental unit in Brooklyn · ★4.82 · 1 bedroom · ...    56246
# 16  14434  Rental unit in Brooklyn · ★4.56 · 1 bedroom · ...     7356
# 17  15341  Condo in New York · ★4.56 · 1 bedroom · 2 beds...    60049
# 18  15385  Rental unit in Brooklyn · ★4.87 · 1 bedroom · ...    60252
# 19  15396  Rental unit in New York · ★5.0 · 2 bedrooms · ...    60278
#
#          host_name neighbourhood_group       neighbourhood   latitude  \
# 0         Jennifer           Manhattan             Midtown  40.753560
# 1            Garon            Brooklyn  Bedford-Stuyvesant  40.685350
# 2    Allen & Irina            Brooklyn        Williamsburg  40.709350
# 3              Kae           Manhattan         East Harlem  40.801070
# 4           Joelle            Brooklyn        Williamsburg  40.712480
# 5             Jane            Brooklyn         Fort Greene  40.691940
# 6            Chaya            Brooklyn        Williamsburg  40.718807
# 7         Nathalie            Brooklyn  Bedford-Stuyvesant  40.684620
# 8            Tommi           Manhattan      Hell's Kitchen  40.767240
# 9           Angela            Brooklyn  Bedford-Stuyvesant  40.682940
# 10         Harriet            Brooklyn            Flatbush  40.637020
# 11          Edward           Manhattan        East Village  40.722960
# 12         Orestes              Queens    Long Island City  40.747570
# 13        Adreinne            Brooklyn  Bedford-Stuyvesant  40.679460
# 14  JT And Tiziana            Brooklyn  Bedford-Stuyvesant  40.680640
# 15          Jeanne            Brooklyn          Greenpoint  40.735350
# 16           Garon            Brooklyn  Bedford-Stuyvesant  40.687770
# 17             Ted           Manhattan     Lower East Side  40.721359
# 18        Cristina            Brooklyn        Williamsburg  40.712110
# 19           Petra           Manhattan             Chelsea  40.744930
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.985590  Entire home/apt    240              30                 49
# 1  -73.955120     Private room     66              30                 50
# 2  -73.953420  Entire home/apt     81              30                191
# 3  -73.942550     Private room     65              30                  1
# 4  -73.958810     Private room     95              30                 13
# 5  -73.973890     Private room    205               2                347
# 6  -73.956177  Entire home/apt    350              30                 11
# 7  -73.938390  Entire home/apt    160              30                189
# 8  -73.986640  Entire home/apt    175              45                 58
# 9  -73.956820     Private room     90              30                 84
# 10 -73.963270     Private room    150              30                  0
# 11 -73.983830     Private room     70              30                313
# 12 -73.945710     Private room    165              30                385
# 13 -73.954170  Entire home/apt    125              30                 76
# 14 -73.940390     Private room     94              30                199
# 15 -73.955840  Entire home/apt    129              30                180
# 16 -73.949760     Private room     70              30                 60
# 17 -73.993668  Entire home/apt    173              30                 37
# 18 -73.963970     Private room     92              30                 55
# 19 -73.995210  Entire home/apt    400              90                  5
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# 0   2022-06-21               0.29                               3
# 1   2019-12-02               0.29                               2
# 2   2023-08-14               1.09                               1
# 3   2022-06-05               0.06                               2
# 4   2022-09-12               0.08                               2
# 5   2023-09-24               2.08                               2
# 6   2023-09-16               0.06                               1
# 7   2023-08-21               1.10                               2
# 8   2017-08-13               0.34                               1
# 9   2023-09-16               0.51                               4
# 10         NaN                NaN                               1
# 11  2023-09-16               1.85                               1
# 12  2023-09-20               2.38                               1
# 13  2023-05-01               0.45                               1
# 14  2023-09-20               1.23                               2
# 15  2023-09-01               1.07                               1
# 16  2022-06-01               0.37                               2
# 17  2023-09-30               0.30                               1
# 18  2023-09-06               0.34                               1
# 19  2018-11-03               0.05                               1
#
#     availability_365  number_of_reviews_ltm             license
# 0                351                      0                 NaN
# 1                151                      0                 NaN
# 2                 79                      5                 NaN
# 3                295                      0                 NaN
# 4                 26                      0                 NaN
# 5                280                     38  OSE-STRREG-0000008
# 6                245                      2                 NaN
# 7                343                     32                 NaN
# 8                337                      0                 NaN
# 9                122                      2                 NaN
# 10                 0                      0                 NaN
# 11               154                     29                 NaN
# 12               217                     46                 NaN
# 13               304                      3                 NaN
# 14                 0                     25                 NaN
# 15               240                      1                 NaN
# 16                 0                      0                 NaN
# 17               149                      4                 NaN
# 18               210                      6                 NaN
# 19                95                      0                 NaN
